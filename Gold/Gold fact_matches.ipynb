# %%
import pyspark.sql.functions as F
from pyspark.sql.window import Window

# %% [markdown]
# #Loading from silver layer

# %%
df = spark.table('tennislakehouse.silver.matches')

# %% [markdown]
# #Writing to gold layer with new id

# %%
w = Window.orderBy(
    'tournament_date',
    'tournament_name'
)

df = df.withColumn(
    'record_id',
    F.row_number().over(w)
)

df = df.select(
    "record_id",
    *[c for c in df.columns if c != "record_id"]
)

(
df.write
    .mode('overwrite')
    .format('delta')
    .option('mergeSchema', 'true')
    .saveAsTable('tennislakehouse.gold.fact_matches')
)
