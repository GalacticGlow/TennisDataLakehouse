# %% [markdown]
# #Loading data from silver

# %%
df = spark.table('tennislakehouse.silver.players')

# %% [markdown]
# #Writing to gold layer

# %%
(
df.write
    .mode('overwrite')
    .format('delta')
    .saveAsTable('tennislakehouse.gold.dim_players')
)
